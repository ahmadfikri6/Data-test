# %%
#import library
import docx
import json
import os
import re

os.getcwd()
# Out:
# 'C:\\Users\\Fikri\\Documents\\Jupyter\\Text To Speech Widaya Wicara\\Train 1'

# %%
docum = open("Record.docx","rb")

# membuat word reader object
document = docx.Document(docum)

#membuat variabel yang kosong untuk temporary
docu=""
for para in document.paragraphs:
       docu += para.text

# %%
sentences = re.findall(r'([a-zA-Z]+)\:([\w]+[\D]+\.)',docu)
for i in sentences:
    print (i)
# Out:
# ('andri', 'selamat siang.')
# ('andri', 'halo.')
# ('andri', 'Nindy.')
# ('andri', 'toko baju sing melu.')
# ('andri', 'Kenalkan nama saya Joko.')
# ('yoga', 'cek cek cek.')
# ('andri', 'ngomong opo.')
# ('andri', 'Terjemahkan sini terus ngomong sih.')
# ('andri', 'pakai bahasa Indonesia terus ngecek dulu apa namanya suaranya masuk ke Trans apa enggak Soalnya ke transfer dari tadi nama Kuto.')
# ('andri', '10 detik aja Udin.')
# ('andri', 'bentar ya.')
# ('andri', 'Yoga.')
# ('andri', 'ini Mas sama-sama ya.')
# ('yoga', 'halo.')
# ('yoga', 'Udan deres karo angin.')
# ('andri', 'cuaca.')
# ('andri', 'kau keong racun.')
# ('andri', 'telur.')
# ('andri', 'selamat sore.')
# ('yoga', 'selamat.')
# ('andri', 'Ayo kita ke angkringan sebelah.')
# ('muizz', 'selamat sore.')
# ('muizz', 'Horas bah.')
# ('muizz', 'aku teh.')
# ('andri', 'mungkin ini akan segera dimulai.')
# ('andri', 'untuk mempersiapkan diri.')
# ('muizz', 'cek cek.')
# ('muizz', 'Halo Halo Neng.')
# ...

# %%
# resultant dictionary
dict1 = {}
  
# fields in the sample file 
fields =['Desc', 'isi']
  
with open('My Record314.json', 'w' ) as fh:
    j = json.dumps(sentences)
      
  
      
    # count variable for employee id creation
    l = 1
      
    for line in fh:
          
        # reading line by line from the text file
        description = list( line.strip().split(None, 4))
          
        # for output see below
        print(description) 
          
        # for automatic creation of id for each employee
        sno ='emp'+str(l)
      
        # loop variable
        i = 0
        # intermediate dictionary
        dict2 = {}
        while i<len(fields):
              
                # creating dictionary for each employee
                dict2[fields[i]]= description[i]
                i = i + 1
                  
        # appending the record of each employee to
        # the main dictionary
        dict1[sno]= dict2
        l = l + 1
  
  
# creating json file        

json.dump(dict1, out_file, indent = 4)
out_file.close()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-4-36a321f16440> in <module>
#      13     l = 1
#      14
# ---> 15     for line in fh:
#      16
#      17         # reading line by line from the text file
#
# UnsupportedOperation: not readable

# %%
# fields in the sample file 
fields =['Desc', 'isi']

with open('My Record316.json', 'w' ) as paragraphs:
    j = json.dumps(sentences)
#     doc = docx.Document()
    
      
#     for paragraph in doc.paragraphs:
          
#         fields = list(paragraph.text(j))
# #         r'([a-zA-Z]+)\:([\w]+[\D]+\.)',docu
          
#         print(paragraph)
          
# #         sno ='emp'+str(l)
      
#         # Perulangan variable
#         i += 1
#         # intermediate dictionary
#         dict = {}
#         while i<len(fields):
              
#                 # creating dictionary for each employee
#                 dict[fields[i]]= description[i]
#                 i += 1
                  
        
# #         dict1[sno]= dict2
# #         l += 1
    
    
    paragraphs.write(j)
    paragraphs.close()

# %%
#membaca file docnya
def ReadingTextDocument(file):
    doc = docx.Document(file)
    full = []
    
    for paragraph in doc.paragraphs:
        full.append(paragraph.text)
        
    return '\n'.join(full)

# %%
print(ReadingTextDocument('Conversation.docx'))
# Out:
# 2021-12-20 16:45:42_andri:
# selamat siang.
#
# 2021-12-20 16:45:51_andri:
# halo.
#
# 2021-12-20 16:46:02_andri:
# Nindy.
#
# 2021-12-20 16:46:09_andri:
# toko baju sing melu.
#
# 2021-12-20 16:46:36_andri:
# Kenalkan nama saya Joko.
#
# 2021-12-20 16:49:57_yoga:
# cek cek cek.
#
# 2021-12-20 16:50:18_andri:
# ngomong opo.
#
# 2021-12-20 16:50:25_andri:
# Terjemahkan sini terus ngomong sih.
#
# 2021-12-20 16:50:35_andri:
# pakai bahasa Indonesia terus ngecek dulu apa namanya suaranya masuk ke Trans apa enggak Soalnya ke transfer dari tadi nama Kuto.
#
# 2021-12-20 16:50:48_andri:
# 10 detik aja Udin.
#
# 2021-12-20 16:51:07_andri:
# bentar ya.
#
# 2021-12-20 16:51:17_andri:
# Yoga.
#
# 2021-12-20 16:51:54_andri:
# ini Mas sama-sama ya.
#
# 2021-12-20 16:52:04_yoga:
# halo.
#
# 2021-12-20 16:52:57_yoga:
# Udan deres karo angin.
#
# 2021-12-20 16:53:02_andri:
# cuaca.
#
# 2021-12-20 16:53:22_andri:
# kau keong racun.
#
# 2021-12-20 16:53:25_andri:
# telur.
#
# ...

# %%
j = json.dumps(ReadingTextDocument('Conversation.docx'))
with open('My Record115.json', 'w' ) as f:
    f.write(j)
    f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-86f30102efe9> in <module>
# ----> 1 j = json.dumps(ReadingTextDocument('Conversation.docx'))
#       2 with open('My Record115.json', 'w' ) as f:
#       3     f.write(j)
#       4     f.close()
#
# NameError: name 'ReadingTextDocument' is not defined

# %%
# resultant dictionary
dict1 = {}
  
# fields in the sample file 
fields =['Desc', 'isi']
  
with open(j) as paragraphs:
    doc = docx.Document()
      
      
    # count variable for employee id creation
    l = 1
      
    for paragraph in doc.paragraphs:
          
        # reading line by line from the text file
        description = list( line.strip().split(None, 2))
          
        # for output see below
        print(description)
          
        # for automatic creation of id for each employee
        sno ='emp'+str(l)
      
        # loop variable
        i = 0
        # intermediate dictionary
        dict2 = {}
        while i<len(fields):
              
                # creating dictionary for each employee
                dict2[fields[i]]= description[i]
                i = i + 1
                  
        # appending the record of each employee to
        # the main dictionary
        dict1[sno]= dict2
        l = l + 1
  
  
# creating json file        
out_file = open("test2.json", "w")
json.dump(dict1, out_file, indent = 4)
out_file.close()

# %%
rgx = re.findall(r'([\w+\-*\:]*[\w+\.])',ReadingTextDocument('Record.docx').split())
print(rgx)

# %%
rgx = re.findall(r'([\D+\:+\_]*[\w])',ReadingTextDocument('Record.docx'))  
print(rgx)

# %%
ReadingTextDocument('Record.docx')

# %%
print(ReadingTextDocument('Record.docx').split())

# %%
# Belajar Regular Expression (REGEX)
def PisahDenganRegex(file):
    doc = re.docx.Document.findal('Record.docx')
    
    completedText = []
    
    for paragraph in doc.paragraphs:
        completedText.append(paragraph.text)
        
#     for paragraph in doc.
               
    return '\n'.join(completedText)

# %%
PisahDenganRegex('Record.docx')

# %%
def extract_names(filename):
    items = []
    name_to_rank = {}
    f = open('Record.docx', 'r')
    text = f.read()
    items = re.findall(r'(\w+)\[=:]\Popularity\sin\s(\d\d\d\d)', text)
    
    
    
    2021-12-20 16:45:42_andri: selamat siang.

# %%
Baca = json.load(open('My Record11.json'))
print(Baca)
